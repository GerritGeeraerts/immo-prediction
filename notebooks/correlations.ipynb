# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # load data and plot correlation matrix

# %%
df = pd.read_csv("../data/raw/immo-data.csv", low_memory=False)
df.head()
# Out:
#          ID   Locality Postal Code  Build Year  Facades  Habitable Surface  \
# 0  11134024    Schilde       2970a      2024.0      4.0              610.0
# 1  11188967      Uccle        1180      2013.0      4.0              840.0
# 2   9789173    Ixelles        1050      1894.0      3.0                NaN
# 3  11180831      Uccle        1180      2013.0      4.0              840.0
# 4  11175109  Vilvoorde        1800      1960.0      4.0              570.0
#
#    Land Surface   Type               Subtype    Price  ... Has starting Price  \
# 0        9910.0  HOUSE                 VILLA  3995000  ...              False
# 1        4425.0  HOUSE                 HOUSE  4950000  ...              False
# 2         421.0  HOUSE    MIXED_USE_BUILDING  4990000  ...              False
# 3        4425.0  HOUSE  EXCEPTIONAL_PROPERTY  4950000  ...              False
# 4         747.0  HOUSE       APARTMENT_BLOCK  1850000  ...              False
#
#    Transaction Subtype  Heating Type  Is Holiday Property  \
# 0          BUY_REGULAR           NaN                  NaN
# 1          BUY_REGULAR           NaN                  NaN
# 2          BUY_REGULAR           GAS                  NaN
# 3          BUY_REGULAR           GAS                  NaN
# 4          BUY_REGULAR           GAS                  NaN
#
#    Gas Water Electricity      Sewer  Sea view Parking count inside  \
# 0                    NaN  CONNECTED       NaN                  3.0
# 1                    NaN        NaN       NaN                  2.0
# 2                   True  CONNECTED       NaN                  NaN
# 3                   True        NaN       NaN                  2.0
# 4                   True  CONNECTED       NaN                  NaN
#
#    Parking count outside                                                url
# 0                    5.0  https://www.immoweb.be/en/classified/house/for...
# 1                    2.0  https://www.immoweb.be/en/classified/house/for...
# 2                    NaN  https://www.immoweb.be/en/classified/house/for...
# 3                    4.0  https://www.immoweb.be/en/classified/house/for...
# 4                    NaN  https://www.immoweb.be/en/classified/house/for...
#
# [5 rows x 42 columns]

# %%
# drop all the columns that are not numeric
df = df.select_dtypes(include=['float64', 'int64'])
# plot correlation matrix with mathplotlib no seaborn
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap='coolwarm')
# Out:
# <Axes: >
